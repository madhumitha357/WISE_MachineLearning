# %% [markdown]
# ## **Library Declaration**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import warnings
warnings.filterwarnings('ignore', category = RuntimeWarning)
warnings.filterwarnings('ignore', category = UserWarning)

# Importing Normalisation library
from sklearn.preprocessing import MinMaxScaler

# Importing Keras libraries and Packages
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# Importing Metrics libraries
import math
from sklearn.metrics import mean_squared_error

# Importing TPU Setup Libraries
# tf.enable_eager_execution()
# from keras.backend import clear_session

# %% [markdown]
# ## **Reading Data**

# %%
data_train = pd.read_csv('/content/Google_Stock_Price_Train.csv')

# %% [markdown]
# ## **Data Pre-processing**

# %%
data_train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_set = data_train.iloc[:, 1:2].values
training_set
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %% [markdown]
# # **Feature Scaling**
# ### 1 to 60 -> 61
# ### 2 to 61 -> 62
# ### 3 to 62 -> 63

# %%
sc = MinMaxScaler(feature_range= (0,1))

# %%
scaled_training_set = sc.fit_transform(training_set)
scaled_training_set
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %% [markdown]
# ## **Creating Datastructure with 60 timesteps and 1 output**

# %%
# Using Pandas and Slicing

x_train, y_train = zip(*[(scaled_training_set[i-60:i, 0]
                          ,scaled_training_set[i, 0])
                          for i in range(60, 767)])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape[1]
# Out:
# 60

# %% [markdown]
# ## **Reshaping**

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %% [markdown]
# ## **Setting Model Parameters**

# %%
INPUT_SHAPE = (x_train.shape[1], 1)
BATCH_SIZE = 32

# %% [markdown]
# # **Model Creation**

# %%
# Step 1 - Initialising the RNN
rnn_regressor = Sequential()

# %%
# Step 2 - First LSTM and Droput Layer
rnn_regressor.add(LSTM(units = 50, return_sequences = True, input_shape = INPUT_SHAPE))
rnn_regressor.add(Dropout(0.2))

# %%
# Step 3 - Additional LSTM and Dropout Layers
rnn_regressor.add(LSTM(units = 50, return_sequences = True))
rnn_regressor.add(Dropout(0.2))

rnn_regressor.add(LSTM(units = 75, return_sequences = True))
rnn_regressor.add(Dropout(0.2))

rnn_regressor.add(LSTM(units = 100, return_sequences = True))
rnn_regressor.add(Dropout(0.2))

rnn_regressor.add(LSTM(units = 100))
rnn_regressor.add(Dropout(0.2))

# %%
# Step 4 - Full Connection
rnn_regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
rnn_regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Summary of RNN model
rnn_regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 75)            37800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 75)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 60, 100)           70400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 100)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 219,301
# Trainable params: 219,301
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **Train the RNN Model**

# %%
EPOCHS = 100
history = rnn_regressor.fit(
    x = x_train,
    y = y_train,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE
)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 11s 166ms/step - loss: 0.0573
# Epoch 2/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0052
# Epoch 3/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0032
# Epoch 4/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0029
# Epoch 5/100
# 23/23 [==============================] - 4s 188ms/step - loss: 0.0026
# Epoch 6/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0029
# Epoch 7/100
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0025
# Epoch 8/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0025
# Epoch 9/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0027
# Epoch 10/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0025
# Epoch 11/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0023
# Epoch 12/100
# 23/23 [==============================] - 4s 189ms/step - loss: 0.0029
# Epoch 13/100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0022
# Epoch 14/100
# 23/23 [==============================] - 4s 183ms/step - loss: 0.0024
# Epoch 15/100
# 23/23 [==============================] - 4s 187ms/step - loss: 0.0028
# Epoch 16/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0019
# Epoch 17/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.0019
# Epoch 18/100
# 23/23 [==============================] - 4s 185ms/step - loss: 0.
100
# 23/23 [==============================] - 4s 186ms/step - loss: 0.0012
# Epoch 87/100
# 23/23 [==============================] - 4s 187ms/step - loss: 8.6107e-04
# Epoch 88/100
# 23/23 [==============================] - 4s 183ms/step - loss: 8.1372e-04
# Epoch 89/100
# 23/23 [==============================] - 4s 184ms/step - loss: 9.5210e-04
# Epoch 90/100
# 23/23 [==============================] - 4s 190ms/step - loss: 8.8737e-04
# Epoch 91/100
# 23/23 [==============================] - 4s 185ms/step - loss: 8.0836e-04
# Epoch 92/100
# 23/23 [==============================] - 4s 185ms/step - loss: 8.7977e-04
# Epoch 93/100
# 23/23 [==============================] - 4s 184ms/step - loss: 7.2327e-04
# Epoch 94/100
# 23/23 [==============================] - 4s 184ms/step - loss: 0.0011
# Epoch 95/100
# 23/23 [==============================] - 4s 186ms/step - loss: 8.4614e-04
# Epoch 96/100
# 23/23 [==============================] - 4s 184ms/step - loss: 7.6028e-04
# Epoch 97/100
# 23/23 [==============================] - 4s 184ms/step - loss: 8.0900e-04
# Epoch 98/100
# 23/23 [==============================] - 4s 184ms/step - loss: 7.4215e-04
# Epoch 99/100
# 23/23 [==============================] - 4s 188ms/step - loss: 7.1639e-04
# Epoch 100/100
# 23/23 [==============================] - 4s 183ms/step - loss: 7.8978e-04

# %% [markdown]
# ## **Prediction and Visualising the result**

# %%
data_test = pd.read_csv('/content/Google_Stock_Price_Test.csv')

# %%
# Real stock Price
real_stock_price = data_test.iloc[:, 1:2].values

# %%
real_stock_price
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
# Predicting Stock Price of Jan 2017
data_total = pd.concat((data_train['Open'], data_test['Open']), axis = 0)
inputs = data_total[len(data_total) - len(data_test) - 60:].values  # values for making this a numpy array

# Reshaping
inputs = inputs.reshape(-1,1)

# %%
# Scaling
inputs = sc.transform(inputs) 
# transform must be used instead of fit_transform to apply the same tranformation which occured in the training set

# %%
# Creating Datastructure with 60 timesteps for test data
x_test = [inputs[i-60:i, 0] for i in range(60, 80)]    # For 20 Financial days
x_test = np.array(x_test)

# %%
# Reshaping
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# ## **Prediction of Test Data with Trained RNN**

# %%
predicted_stock_price = rnn_regressor.predict(x_test)

# %%
# Inversing the scaled data to original
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[735.961  ],
#        [734.15234],
#        [733.3115 ],
#        [733.3641 ],
#        [734.7926 ],
#        [738.08905],
#        [742.1841 ],
#        [745.3883 ],
#        [747.32306],
#        [748.186  ],
#        [748.3107 ],
#        [747.94324],
#        [747.3518 ],
#        [747.00433],
#        [747.03723],
#        [748.9317 ],
#        [752.7879 ],
#        [757.976  ],
#        [762.4734 ],
#        [763.1268 ]], dtype=float32)

# %% [markdown]
# # **Visualisation**

# %%
plt.figure(figsize=(16, 5))
plt.plot(real_stock_price, color = 'blue', label = 'Real Stock Price of JAN 2017')
plt.plot(predicted_stock_price, color = 'orange', label = 'Predicted Stock Price of JAN 2017')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## **Performance Evaluation**

# %%
rmse = math.sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('Root Mean Squared Error of our RNN model: {}'.format(rmse))
# Out:
# Root Mean Squared Error of our RNN model: 62.90373290655438
